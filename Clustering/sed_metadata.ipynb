# %% [markdown]
# ## Metadata analyses by clusters - sediment

# %% [markdown]
# Comments: There were many great suggestions on what to look at in the 3 clusters; for example:
# <li>A. molecular properties such as diversity indices, classes (i.e. lignin, aliphatic compounds), NOSC, H/C and O/C ratios, DBE, AI_Mod…..
# <li>B. a focus on environmental processes: NPOC/Fe representing more "terrestrial" inputs VS 18O/2H that might represent more groundsed inputs
# <br>We should also try and create a plot for ’NPOC vs Fe’ and ‘18O vs 2H’.
# <br>The more molecular stuff maybe as well in a similar way ? ‘H/C vs O/C’  ?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

sns.set_theme()

# %%
# Metadata
metadata = pd.read_csv('../Dataset/FTICR_meta_all_2021-09-29.csv').set_index('ID')
print('Metadata: ' + str(metadata.shape))
label1 = pd.read_csv('water_cluster_label.csv')
print('sed: ' + str(label1.shape))
label2 = pd.read_csv('sediment_cluster_label.csv')
print('Sediment: ' + str(label2.shape))
label = pd.concat([label1,label2], axis=0)

label = label.set_index('sample_id')

df = metadata.join(label,how='left')

df.head()
# Out:
# Metadata: (504, 69)
# sed: (265, 2)
# Sediment: (239, 2)
#                         river.id sample.type location.id sampling.type  \
# ID
# SED_S19S.0001_D_Field  S19S.0001         SED           D         Field
# SED_S19S.0001_M_Field  S19S.0001         SED           M         Field
# SED_S19S.0001_U_Field  S19S.0001         SED           U         Field
# SED_S19S.0003_D_Field  S19S.0003         SED           D         Field
# SED_S19S.0003_M_Field  S19S.0003         SED           M         Field
#
#                        replicate.id                    original.id       Date  \
# ID
# SED_S19S.0001_D_Field           NaN   S19S_0001_Sed_Field_ICR.D_p2  19-Sep-19
# SED_S19S.0001_M_Field           NaN   S19S_0001_Sed_Field_ICR.M_p2  19-Sep-19
# SED_S19S.0001_U_Field           NaN   S19S_0001_Sed_Field_ICR.U_p2  19-Sep-19
# SED_S19S.0003_D_Field           NaN  S19S_0003_Sed_Field_ICR.D_p15   8-Sep-19
# SED_S19S.0003_M_Field           NaN  S19S_0003_Sed_Field_ICR.M_p15   8-Sep-19
#
#                       Start_Time Time_zone Stream_Name  Stream_Order  \
# ID
# SED_S19S.0001_D_Field      12:00       PST      Fraser           9.0
# SED_S19S.0001_M_Field      12:00       PST      Fraser           9.0
# SED_S19S.0001_U_Field      12:00       PST      Fraser           9.0
# SED_S19S.0003_D_Field      15:15       PST   Thompson            7.0
# SED_S19S.0003_M_Field      15:15       PST   Thompson            7.0
#
#                            City State_or_Province Country General_Vegetation  \
# ID
# SED_S19S.0001_D_Field      Hope  British Columbia  Canada              Grass
# SED_S19S.0001_M_Field      Hope  British Columbia  Canada              Grass
# SED_S19S.0001_U_Field      Hope  British Columbia  Canada              Grass
# SED_S19S.0003_D_Field  Kamloops  British Columbia  Canada      Not vegetated
# SED_S19S.0003_M_Field  Kamloops  British Columbia  Canada      Not vegetated
#
#                              Weather         Hydrogeomorphology  \
# ID
# SED_S19S.0001_D_Field  Partly cloudy  Single-channel meandering
# SED_S19S.0001_M_Field  Partly cloudy  Single-channel meandering
# SED_S19S.0001_U_Field  Partly cloudy  Single-channel meandering
# SED_S19S.0003_D_Field  Partly cloudy    Single-channel straight
# SED_S19S.0003_M_Field  Partly cloudy    Single-channel straight
#
#                                                        River_Gradient  \
# ID
# SED_S19S.0001_D_Field  Relatively flat/gentle gradient (e.g. valleys)
# SED_S19S.0001_M_Field  Relatively flat/gentle gradient (e.g. valleys)
# SED_S19S.0001_U_Field  Relatively flat/gentle gradient (e.g. valleys)
# SED_S19S.0003_D_Field  Relatively flat/gentle gradient (e.g. valleys)
# SED_S19S.0003_M_Field  Relatively flat/gentle gradient (e.g. valleys)
#
#                       Intermittent_or_Perennial              Sediment  \
# ID
# SED_S19S.0001_D_Field                 Perennial                  Sand
# SED_S19S.0001_M_Field                 Perennial                  Sand
# SED_S19S.0001_U_Field                 Perennial                  Sand
# SED_S19S.0003_D_Field                 Perennial  Silt/mud (<0.0625mm)
# SED_S19S.0003_M_Field                 Perennial  Silt/mud (<0.0625mm)
#
#                        Distance_DS.and.MS_meters  Distance_MS.and.US_meters  \
# ID
# SED_S19S.0001_D_Field                       15.0                       15.0
# SED_S19S.0001_M_Field                       15.0                       15.0
# SED_S19S.0001_U_Field                       15.0                       15.0
# SED_S19S.0003_D_Field                       10.0                       10.0
# SED_S19S.0003_M_Field                       10.0                       10.0
#
#                               Primary.Sources.Flow.Variation   pH Temp_degC  \
# ID
# SED_S19S.0001_D_Field  Natural flow (seasonal). Glacial melt  NaN       NaN
# SED_S19S.0001_M_Field  Natural flow (seasonal). Glacial melt  NaN       NaN
# SED_S19S.0001_U_Field  Natural flow (seasonal). Glacial melt  NaN       NaN
# SED_S19S.0003_D_Field  Natural flow (seasonal). Glacial melt  NaN       NaN
# SED_S19S.0003_M_Field  Natural flow (seasonal). Glacial melt  NaN       NaN
#
#                       DO_perc.sat DO_mg.per.L Algal.Mat.Coverage  \
# ID
# SED_S19S.0001_D_Field         NaN         NaN                 No
# SED_S19S.0001_M_Field         NaN         NaN                 No
# SED_S19S.0001_U_Field         NaN         NaN                 No
# SED_S19S.0003_D_Field         NaN         NaN                Low
# SED_S19S.0003_M_Field         NaN         NaN                Low
#
#                                    Depositional.Type  Latitude_dec.deg  \
# ID
# SED_S19S.0001_D_Field  Shallow waters near the shore          49.38609
# SED_S19S.0001_M_Field  Shallow waters near the shore          49.38626
# SED_S19S.0001_U_Field  Shallow waters near the shore          49.38639
# SED_S19S.0003_D_Field  Shallow waters near the shore          50.68880
# SED_S19S.0003_M_Field  Shallow waters near the shore          50.68883
#
#                        Longitude_dec.deg Macrophyte.Coverage  \
# ID
# SED_S19S.0001_D_Field         -121.45047                  No
# SED_S19S.0001_M_Field         -121.45055                  No
# SED_S19S.0001_U_Field         -121.45063                 Low
# SED_S19S.0003_D_Field         -120.36647                  No
# SED_S19S.0003_M_Field         -120.36647                  No
#
#                         Sunlight.Access_Perc.Canopy.Cover  \
# ID
# SED_S19S.0001_D_Field  Full sunlight (0-20% canopy cover)
# SED_S19S.0001_M_Field  Full sunlight (0-20% canopy cover)
# SED_S19S.0001_U_Field  Full sunlight (0-20% canopy cover)
# SED_S19S.0003_D_Field  Full sunlight (0-20% canopy cover)
# SED_S19S.0003_M_Field  Full sunlight (0-20% canopy cover)
#
#                       Water.Column.Height_cm         Sampler_Organization  \
# ID
# SED_S19S.0001_D_Field                     17   Thompson Rivers University
# SED_S19S.0001_M_Field                     16   Thompson Rivers University
# SED_S19S.0001_U_Field                     19   Thompson Rivers University
# SED_S19S.0003_D_Field                     35  Thompson Rivers University
# SED_S19S.0003_M_Field                     30  Thompson Rivers University
#
#                       Associated_Site Sampler_Name  \
# ID
# SED_S19S.0001_D_Field             NaN  Eric Bottos
# SED_S19S.0001_M_Field             NaN  Eric Bottos
# SED_S19S.0001_U_Field             NaN  Eric Bottos
# SED_S19S.0003_D_Field             NaN  Eric Bottos
# SED_S19S.0003_M_Field             NaN  Eric Bottos
#
#                       Approx.Distance.From.Gauge_meters  \
# ID
# SED_S19S.0001_D_Field                               100
# SED_S19S.0001_M_Field                               100
# SED_S19S.0001_U_Field                               100
# SED_S19S.0003_D_Field                               100
# SED_S19S.0003_M_Field                               100
#
#                                                           Discharge_Link  \
# ID
# SED_S19S.0001_D_Field  https://wateroffice.ec.gc.ca/report/real_time_...
# SED_S19S.0001_M_Field  https://wateroffice.ec.gc.ca/report/real_time_...
# SED_S19S.0001_U_Field  https://wateroffice.ec.gc.ca/report/real_time_...
# SED_S19S.0003_D_Field  https://wateroffice.ec.gc.ca/report/real_time_...
# SED_S19S.0003_M_Field  https://wateroffice.ec.gc.ca/report/real_time_...
#
#                       US.or.DS.of.Gauge  Gauge_Latitude_dec.deg  \
# ID
# SED_S19S.0001_D_Field        Downstream                49.38583
# SED_S19S.0001_M_Field        Downstream                49.38583
# SED_S19S.0001_U_Field        Downstream                49.38583
# SED_S19S.0003_D_Field        Downstream                50.68750
# SED_S19S.0003_M_Field        Downstream                50.68750
#
#                        Gauge_Longitude_dec.deg Met.Station.Nearby  \
# ID
# SED_S19S.0001_D_Field               -121.45416                Yes
# SED_S19S.0001_M_Field               -121.45416                Yes
# SED_S19S.0001_U_Field               -121.45416                Yes
# SED_S19S.0003_D_Field               -120.36388                Yes
# SED_S19S.0003_M_Field               -120.36388                Yes
#
#                                                              Met.Station  \
# ID
# SED_S19S.0001_D_Field  Hope A: https://climate.weather.gc.ca/climate_...
# SED_S19S.0001_M_Field  Hope A: https://climate.weather.gc.ca/climate_...
# SED_S19S.0001_U_Field  Hope A: https://climate.weather.gc.ca/climate_...
# SED_S19S.0003_D_Field  Kamloops A: https://climate.weather.gc.ca/clim...
# SED_S19S.0003_M_Field  Kamloops A: https://climate.weather.gc.ca/clim...
#
#                       Precipitation.Within.Week Number.Days.Since.Precip  \
# ID
# SED_S19S.0001_D_Field                       Yes                        1
# SED_S19S.0001_M_Field                       Yes                        1
# SED_S19S.0001_U_Field                       Yes                        1
# SED_S19S.0003_D_Field                       Yes                        1
# SED_S19S.0003_M_Field                       Yes                        1
#
#                       Dam.Upstream.Site  Dam Contamination.Source.Upstream  \
# ID
# SED_S19S.0001_D_Field                No  NaN                           Yes
# SED_S19S.0001_M_Field                No  NaN                           Yes
# SED_S19S.0001_U_Field                No  NaN                           Yes
# SED_S19S.0003_D_Field                No  NaN                           Yes
# SED_S19S.0003_M_Field                No  NaN                           Yes
#
#                                                     Contamination.Source  \
# ID
# SED_S19S.0001_D_Field  Town of Hope. population of ~6100. 0m from sam...
# SED_S19S.0001_M_Field  Town of Hope. population of ~6100. 0m from sam...
# SED_S19S.0001_U_Field  Town of Hope. population of ~6100. 0m from sam...
# SED_S19S.0003_D_Field  City of Kamloops. population of ~90.000. sampl...
# SED_S19S.0003_M_Field  City of Kamloops. population of ~90.000. sampl...
#
#                       Water.Quality.Data.Available  \
# ID
# SED_S19S.0001_D_Field                          Yes
# SED_S19S.0001_M_Field                          Yes
# SED_S19S.0001_U_Field                          Yes
# SED_S19S.0003_D_Field                           No
# SED_S19S.0003_M_Field                           No
#
#                                                       Water.Quality.Data  \
# ID
# SED_S19S.0001_D_Field  Turbidity. Specific Conductivity. Temperature....
# SED_S19S.0001_M_Field  Turbidity. Specific Conductivity. Temperature....
# SED_S19S.0001_U_Field  Turbidity. Specific Conductivity. Temperature....
# SED_S19S.0003_D_Field                                                NaN
# SED_S19S.0003_M_Field                                                NaN
#
#                                                               Known.Data  \
# ID
# SED_S19S.0001_D_Field  Specific Conductivity: 116.58 uS/cm http://aqu...
# SED_S19S.0001_M_Field  Specific Conductivity: 116.58 uS/cm http://aqu...
# SED_S19S.0001_U_Field  Specific Conductivity: 116.58 uS/cm http://aqu...
# SED_S19S.0003_D_Field                                                NaN
# SED_S19S.0003_M_Field                                                NaN
#
#                       Published.Work.On.Site  \
# ID
# SED_S19S.0001_D_Field                    NaN
# SED_S19S.0001_M_Field                    NaN
# SED_S19S.0001_U_Field                    NaN
# SED_S19S.0003_D_Field                     No
# SED_S19S.0003_M_Field                     No
#
#                                                           Published.Work  \
# ID
# SED_S19S.0001_D_Field  https://www.jstor.org/stable/4251587?seq=1#met...
# SED_S19S.0001_M_Field  https://www.jstor.org/stable/4251587?seq=1#met...
# SED_S19S.0001_U_Field  https://www.jstor.org/stable/4251587?seq=1#met...
# SED_S19S.0003_D_Field                                                NaN
# SED_S19S.0003_M_Field                                                NaN
#
#                       Notes    Study_Code  resprate_mg.L.h  resp.inc.time.min  \
# ID
# SED_S19S.0001_D_Field   NaN  WHONDRS_S19S              NaN                NaN
# SED_S19S.0001_M_Field   NaN  WHONDRS_S19S              NaN                NaN
# SED_S19S.0001_U_Field   NaN  WHONDRS_S19S              NaN                NaN
# SED_S19S.0003_D_Field   NaN  WHONDRS_S19S              NaN                NaN
# SED_S19S.0003_M_Field   NaN  WHONDRS_S19S              NaN                NaN
#
#                        resp.r2  resp.pval  NPOC_mg.L.asC  del2H_permil  \
# ID
# SED_S19S.0001_D_Field      NaN        NaN           2.35           NaN
# SED_S19S.0001_M_Field      NaN        NaN           2.50           NaN
# SED_S19S.0001_U_Field      NaN        NaN           3.17           NaN
# SED_S19S.0003_D_Field      NaN        NaN          17.21           NaN
# SED_S19S.0003_M_Field      NaN        NaN          30.92           NaN
#
#                        del18O_permil  Cl_mgL  SO4_mgL  NO3_mgL  NO2_mgL  \
# ID
# SED_S19S.0001_D_Field            NaN     NaN      NaN      NaN      NaN
# SED_S19S.0001_M_Field            NaN     NaN      NaN      NaN      NaN
# SED_S19S.0001_U_Field            NaN     NaN      NaN      NaN      NaN
# SED_S19S.0003_D_Field            NaN     NaN      NaN      NaN      NaN
# SED_S19S.0003_M_Field            NaN     NaN      NaN      NaN      NaN
#
#                        F_mgL cluster
# ID
# SED_S19S.0001_D_Field    NaN   sed_2
# SED_S19S.0001_M_Field    NaN   sed_2
# SED_S19S.0001_U_Field    NaN   sed_2
# SED_S19S.0003_D_Field    NaN   sed_2
# SED_S19S.0003_M_Field    NaN   sed_1

# %%
df['cluster'].value_counts()
# Out:
# sw_0     147
# sed_2    146
# sw_2      90
# sed_0     76
# sw_1      28
# sed_1     17
# Name: cluster, dtype: int64

# %%
# # Molecular parameters
# mparams1 = pd.read_csv('../Dataset/sed_Prevalence_10_crosstable_2021-09-29.csv')
# mparams2 = pd.read_csv('../Dataset/Sediment_Prevalence_10_crosstable_2021-09-29.csv')

# %% [markdown]
# ## sed

# %%
dfs = df[df['sample.type']=='SED']

# %% [markdown]
# #### Check missing value per column

# %%
print(" \nCount total NaN at each column in a DataFrame : \n\n", dfs.isnull().sum())
# Out:
#
# Count total NaN at each column in a DataFrame :
#
#  river.id                               0
# sample.type                            0
# location.id                            0
# sampling.type                          0
# replicate.id                         239
# original.id                            0
# Date                                   0
# Start_Time                             0
# Time_zone                              3
# Stream_Name                            0
# Stream_Order                          28
# City                                   0
# State_or_Province                     13
# Country                                0
# General_Vegetation                     0
# Weather                                9
# Hydrogeomorphology                     0
# River_Gradient                         0
# Intermittent_or_Perennial              6
# Sediment                               0
# Distance_DS.and.MS_meters              0
# Distance_MS.and.US_meters              0
# Primary.Sources.Flow.Variation        19
# pH                                   239
# Temp_degC                            239
# DO_perc.sat                          239
# DO_mg.per.L                          239
# Algal.Mat.Coverage                     0
# Depositional.Type                      0
# Latitude_dec.deg                       0
# Longitude_dec.deg                      0
# Macrophyte.Coverage                    0
# Sunlight.Access_Perc.Canopy.Cover      0
# Water.Column.Height_cm                 0
# Sampler_Organization                   0
# Associated_Site                       95
# Sampler_Name                           0
# Approx.Distance.From.Gauge_meters     23
# Discharge_Link                        73
# US.or.DS.of.Gauge                     27
# Gauge_Latitude_dec.deg                66
# Gauge_Longitude_dec.deg               66
# Met.Station.Nearby                    30
# Met.Station                           85
# Precipitation.Within.Week             12
# Number.Days.Since.Precip              87
# Dam.Upstream.Site                     20
# Dam                                  188
# Contamination.Source.Upstream         29
# Contamination.Source                 161
# Water.Quality.Data.Available          31
# Water.Quality.Data                    81
# Known.Data                           128
# Published.Work.On.Site                54
# Published.Work                       144
# Notes                                 83
# Study_Code                             0
# resprate_mg.L.h                       76
# resp.inc.time.min                     76
# resp.r2                               76
# resp.pval                            119
# NPOC_mg.L.asC                          0
# del2H_permil                         239
# del18O_permil                        239
# Cl_mgL                               239
# SO4_mgL                              239
# NO3_mgL                              239
# NO2_mgL                              239
# F_mgL                                239
# cluster                                0
# dtype: int64

# %%
dfs.shape
# Out:
# (239, 70)

# %%
colmiss = ['Stream_Order', #cat
           'Precipitation.Within.Week', #cat
           'Number.Days.Since.Precip', #cat
           'resprate_mg.L.h'] #num

sed = dfs.copy()

# %%
sns.set(rc={'figure.figsize':(20,10)})
f,axs = plt.subplots(2,2)
axs = axs.ravel()

cnt = 0
for i in colmiss:
    if cnt < 3:
        sns.countplot(data=sed, x=i, ax=axs[cnt], hue='cluster').set_title(i)
    if cnt >= 3:
        sns.histplot(data=sed, x=i, ax=axs[cnt], hue='cluster').set_title(i)
    cnt = cnt + 1

# %%
sed.groupby('cluster')[colmiss[-2:]].describe()
# Out:
#         resprate_mg.L.h                                                     \
#                   count      mean        std   min     25%    50%      75%
# cluster
# sed_0              52.0  9.917115  13.196968  0.44  2.5375  5.255  11.9300
# sed_1               6.0  5.000000   4.210178  0.39  1.3550  5.165   7.4825
# sed_2             105.0  6.436190   8.542155  0.10  1.0000  2.370   8.7600
#
#
#            max
# cluster
# sed_0    81.75
# sed_1    10.94
# sed_2    41.85

# %%
sed.dtypes
# Out:
# river.id                              object
# sample.type                           object
# location.id                           object
# sampling.type                         object
# replicate.id                         float64
# original.id                           object
# Date                                  object
# Start_Time                            object
# Time_zone                             object
# Stream_Name                           object
# Stream_Order                         float64
# City                                  object
# State_or_Province                     object
# Country                               object
# General_Vegetation                    object
# Weather                               object
# Hydrogeomorphology                    object
# River_Gradient                        object
# Intermittent_or_Perennial             object
# Sediment                              object
# Distance_DS.and.MS_meters            float64
# Distance_MS.and.US_meters            float64
# Primary.Sources.Flow.Variation        object
# pH                                    object
# Temp_degC                             object
# DO_perc.sat                           object
# DO_mg.per.L                           object
# Algal.Mat.Coverage                    object
# Depositional.Type                     object
# Latitude_dec.deg                     float64
# Longitude_dec.deg                    float64
# Macrophyte.Coverage                   object
# Sunlight.Access_Perc.Canopy.Cover     object
# Water.Column.Height_cm                object
# Sampler_Organization                  object
# Associated_Site                       object
# Sampler_Name                          object
# Approx.Distance.From.Gauge_meters     object
# Discharge_Link                        object
# US.or.DS.of.Gauge                     object
# Gauge_Latitude_dec.deg               float64
# Gauge_Longitude_dec.deg              float64
# Met.Station.Nearby                    object
# Met.Station                           object
# Precipitation.Within.Week             object
# Number.Days.Since.Precip              object
# Dam.Upstream.Site                     object
# Dam                                   object
# Contamination.Source.Upstream         object
# Contamination.Source                  object
# Water.Quality.Data.Available          object
# Water.Quality.Data                    object
# Known.Data                            object
# Published.Work.On.Site                object
# Published.Work                        object
# Notes                                 object
# Study_Code                            object
# resprate_mg.L.h                      float64
# resp.inc.time.min                    float64
# resp.r2                              float64
# resp.pval                            float64
# NPOC_mg.L.asC                        float64
# del2H_permil                         float64
# del18O_permil                        float64
# Cl_mgL                               float64
# SO4_mgL                              float64
# NO3_mgL                              float64
# NO2_mgL                              float64
# F_mgL                                float64
# cluster                               object
# dtype: object

# %%
target = ['cluster']

# %%
# 16
colnum = ['Distance_DS.and.MS_meters',
          'Distance_MS.and.US_meters',
          'Approx.Distance.From.Gauge_meters',
          'Number.Days.Since.Precip',
          'resprate_mg.L.h',
          'NPOC_mg.L.asC']

# Data cleaning

sed.loc[(sed['Approx.Distance.From.Gauge_meters'] == '<100'), 'Approx.Distance.From.Gauge_meters']= 99.0
sed.loc[(sed['Number.Days.Since.Precip'] == '4-Jan'), 'Number.Days.Since.Precip']= 4

sed[colnum] = sed[colnum].astype(float)

# %%
# 12
colcat = ['Country',
          'General_Vegetation',
          'Weather',
          'Hydrogeomorphology',
          'Intermittent_or_Perennial',
          'Sediment',
          'US.or.DS.of.Gauge',
          'Precipitation.Within.Week',
          'Dam.Upstream.Site',
          'Stream_Order',
          'River_Gradient',
          'Primary.Sources.Flow.Variation']

sed[colcat] = sed[colcat].astype(str)

# %% [markdown]
# #### Categorical column

# %%
sns.set(rc={'figure.figsize':(20,40)})
f,axs = plt.subplots(6,2)
axs = axs.ravel()

cnt = 0
for i in colcat:
    sns.countplot(data=sed, x=i, ax=axs[cnt], hue='cluster').set_title(i)
    cnt = cnt + 1

# %% [markdown]
# #### Numerical column

# %%
sns.set(rc={'figure.figsize':(20,20)})
f,axs = plt.subplots(3,2)
axs = axs.ravel()

cnt = 0
for i in colnum:
    sns.histplot(data=sed, x=i, ax=axs[cnt], hue='cluster').set_title(i)
    cnt = cnt + 1

# %%
sns.set(rc={'figure.figsize':(20,20)})
f,axs = plt.subplots(3,2)
axs = axs.ravel()

cnt = 0
for i in colnum:
    sns.boxplot(x='cluster', y=i, data=sed, orient='v', ax=axs[cnt]).set_title(i)
    cnt = cnt + 1

# %%
sns.set(rc={'figure.figsize':(20,20)})
f,axs = plt.subplots(3,2)
axs = axs.ravel()

cnt = 0
for i in colnum:
    sns.boxplot(x='cluster', y=i, data=sed, orient='v', ax=axs[cnt], showfliers = False).set_title(i)
    cnt = cnt + 1

# %% [markdown]
# # Start: Update Jan 2024 - Statistical significance

# %%
sed.cluster.unique()
# Out:
# array(['sed_2', 'sed_1', 'sed_0'], dtype=object)

# %%
#Reference: https://blog.4dcu.be/programming/2021/12/30/Posthoc-Statannotations.html
from scipy.stats import kruskal

# Extract the individual groups from the DataFrame
group0 = sed[sed['cluster'] == 'sed_0'][colnum]
group1 = sed[sed['cluster'] == 'sed_1'][colnum]
group2 = sed[sed['cluster'] == 'sed_2'][colnum]

print('cluster sed_0' + str(group0.shape))
print('cluster sed_1' + str(group1.shape))
print('cluster sed_2' + str(group2.shape))
# Out:
# cluster sed_0(76, 6)
# cluster sed_1(17, 6)
# cluster sed_2(146, 6)

# %%
# Perform the Kruskal-Wallis test after dropping nan values, 
# The function returns two values: the test statistic and the p-value. 
# p-value < 0.05 indicates significant difference in the medians among the three groups.

pv = []
for i in colnum:
    stat, p = kruskal(group0[i].dropna(), group1[i].dropna(), group2[i].dropna()) #note: high missing data in del2H and del180
    print(f'{i}, Statistics={stat}, p={p}')
    pv.append(float('{:,.5f}'.format(p)))
# Out:
# Distance_DS.and.MS_meters, Statistics=0.7822023253500904, p=0.676311735074239
# Distance_MS.and.US_meters, Statistics=2.4160495025735353, p=0.29878687532994447
# Approx.Distance.From.Gauge_meters, Statistics=0.6828987995199248, p=0.7107394302957677
# Number.Days.Since.Precip, Statistics=3.3175716824709878, p=0.19036997921710758
# resprate_mg.L.h, Statistics=8.78495648053475, p=0.012370035283129537
# NPOC_mg.L.asC, Statistics=66.58785639289482, p=3.472407642509963e-15

# %%
from scikit_posthocs import posthoc_dunn

# posthoc dunn test, with correction for multiple testing
for i in colnum:
    dunn_df = posthoc_dunn(sed, val_col=i, group_col="cluster", p_adjust="fdr_bh")
    print(i)
    print(dunn_df)
# Out:
# Distance_DS.and.MS_meters
#           sed_0     sed_1     sed_2
# sed_0  1.000000  0.631515  0.631515
# sed_1  0.631515  1.000000  0.631515
# sed_2  0.631515  0.631515  1.000000
# Distance_MS.and.US_meters
#           sed_0     sed_1     sed_2
# sed_0  1.000000  0.998211  0.435213
# sed_1  0.998211  1.000000  0.629819
# sed_2  0.435213  0.629819  1.000000
# Approx.Distance.From.Gauge_meters
#           sed_0     sed_1     sed_2
# sed_0  1.000000  0.741837  0.741837
# sed_1  0.741837  1.000000  0.741837
# sed_2  0.741837  0.741837  1.000000
# Number.Days.Since.Precip
#           sed_0    sed_1     sed_2
# sed_0  1.000000  0.79627  0.766473
# sed_1  0.796270  1.00000  0.796270
# sed_2  0.766473  0.79627  1.000000
# resprate_mg.L.h
#           sed_0     sed_1     sed_2
# sed_0  1.000000  0.700979  0.132340
# sed_1  0.700979  1.000000  0.946884
# sed_2  0.132340  0.946884  1.000000
# NPOC_mg.L.asC
#               sed_0         sed_1         sed_2
# sed_0  1.000000e+00  2.936319e-02  1.072043e-10
# sed_1  2.936319e-02  1.000000e+00  4.403643e-09
# sed_2  1.072043e-10  4.403643e-09  1.000000e+00

# %%
sns.set(rc={'figure.figsize':(20,20)})
f,axs = plt.subplots(3,2)
axs = axs.ravel()

cnt = 0
for i in colnum:
    sns.boxplot(x='cluster', y=i, data=sed, order=['sed_0', 'sed_1', 'sed_2'], orient='v', ax=axs[cnt], showfliers = False).set_title(i + ', Kruskal-Wallis test, p-value=' + str(pv[cnt]))
    cnt = cnt + 1

# %% [markdown]
# # End: Update Jan 2024 - Statistical significance

# %%
sns.set(rc={'figure.figsize':(20,20)})
f,axs = plt.subplots(3,2)
axs = axs.ravel()

cnt = 0
for i in colnum:
    sns.violinplot(x='cluster', y=i, data=sed, orient='v', ax=axs[cnt]).set_title(i)
    cnt = cnt + 1

# %% [markdown]
# ## Scatterplot

# %%
colnum
# Out:
# ['Distance_DS.and.MS_meters',
#  'Distance_MS.and.US_meters',
#  'Approx.Distance.From.Gauge_meters',
#  'Number.Days.Since.Precip',
#  'resprate_mg.L.h',
#  'NPOC_mg.L.asC']

# %%
## NPOC vs resprate_mg.L.h
sns.set(rc={'figure.figsize':(20,10)})
sns.scatterplot(data=sed, x='NPOC_mg.L.asC', y='resprate_mg.L.h', legend='full', hue='cluster')
# Out:
# <Axes: xlabel='NPOC_mg.L.asC', ylabel='resprate_mg.L.h'>
